# %% [markdown]
# # Intoduction

# %% [markdown]
# **University:** NOVA Information Management School<br/>
# **Program:** Master’s Degree Program in Data Science and Advanced Analytics<br/>
# **Academic Year:** 2022/2023
#
# ```
# ============== Students: ==============
# Iryna Savchuk (m20211310@novaims.unl.pt)
# Cátia Sofia Pereira Parrinha (m20201320@novaims.unl.pt)
# Giulia Bovenga (m20221637@novaims.unl.pt)
# Hubert Oberhauser (m20220628@novaims.unl.pt)
# Leo Allgaier (m20220635@novaims.unl.pt)
# =======================================
# ```
# ------------------------------
# **Data Source**
# *   Clean data to perform model training can be downloaded from here: [datasets.zip](https://drive.google.com/file/d/1xMF-lupg9UX-UZUD6NlC2h-Ao08gQ6f3/view?usp=sharing)
#
# * Original data can be downloaded from here: [train](https://storage.googleapis.com/ibeans/train.zip) - [validation](https://storage.googleapis.com/ibeans/validation.zip) - [test](https://storage.googleapis.com/ibeans/test.zip)
#
# * Original data description: https://github.com/AI-Lab-Makerere/ibean/
#
# ------------------------------
# **References**
#
# Keras Tuner - https://www.tensorflow.org/tutorials/keras/keras_tuner
#
# ------------------------------
# **Summary**
#
# The current notebook features a hyperparameter search for various architectures, including the handcrafted model. Hyperparameter tuning is a crucial step in deep learning model development, as it involves finding the ideal hyperparameter set that maximizes performance on a given task. Keras provides an automated way to do this through the use of the hyperband algorithm, which selectively samples hyperparameter configurations to optimize the search process.
#
# In this particular case, the hyperband algorithm was utilized on three different architectures with two different image sizes (128x128 and 256x256) to identify the best hyperparameter sets for each architecture and image size combination, with the aim of improving task performance.
#
# The hyperband algorithm works by running experiments with various hyperparameter configurations, eliminating poorly performing configurations early on and allocating more resources to promising ones. This approach optimizes the search process while minimizing computational cost.
#
# Overall, Keras' hyperparameter tuning with the hyperband algorithm is a powerful method for enhancing deep learning model performance and can be utilized for a broad range of architectures and tasks. In this instance, it resulted in an improvement of the categorical accuracy in the handcrafted model from --- to 91.4%.
#
# The final section of the notebook summarizes the primary [outcomes](#scrollTo=xgSB_k1Bz26x).
#
#
#
# ------------------------------

# %% [markdown]
# # Installing Keras Tuner

# %%
# !pip install -q -U keras-tuner
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.2/172.2 KB 6.7 MB/s eta 0:00:00

# %% [markdown]
# # Importing Libraries

# %%
import zipfile
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras_tuner as kt
from keras import backend as K
from google.colab import drive
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras.optimizers.experimental import SGD
from tensorflow.keras import Sequential, layers, initializers, regularizers, optimizers, metrics
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import load_model

# %% [markdown]
# # Load Image Datasets in Size 128, 128

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image_size = (128, 128)
crop_to_aspect_ratio = False
labels='inferred'
color_mode="rgb"
batch_size=16
label_mode="categorical"
shuffle=True
seed=42

# %%
ds_train = image_dataset_from_directory("/content/drive/MyDrive/Uni/DL/Project/datasets/datasets/train",
                                        labels=labels,
                                        image_size=image_size,
                                        crop_to_aspect_ratio=crop_to_aspect_ratio,
                                        color_mode=color_mode,
                                        batch_size=batch_size,
                                        label_mode=label_mode,
                                        shuffle=shuffle,
                                        seed=seed
                                        )

ds_validation = image_dataset_from_directory("/content/drive/MyDrive/Uni/DL/Project/datasets/datasets/validation",
                                             labels=labels,
                                             image_size=image_size,
                                             crop_to_aspect_ratio=crop_to_aspect_ratio,
                                             color_mode=color_mode,
                                             batch_size=batch_size,
                                             label_mode=label_mode,
                                             shuffle=shuffle,
                                             seed=seed
                                             )

ds_test = image_dataset_from_directory("/content/drive/MyDrive/Uni/DL/Project/datasets/datasets/test",
                                       labels=labels, 
                                       image_size=image_size,
                                       crop_to_aspect_ratio=crop_to_aspect_ratio,
                                       color_mode=color_mode,
                                       batch_size=batch_size,
                                       label_mode=label_mode,
                                       shuffle=shuffle,
                                       seed=seed
                                       )
# Out:
# Found 1034 files belonging to 3 classes.
# Found 133 files belonging to 3 classes.
# Found 128 files belonging to 3 classes.

# %%
input_shape1 = tuple(iter(ds_train).next()[0].shape[1:])

# %%
input_shape1
# Out:
# (128, 128, 3)

# %% [markdown]
# # Load Image Datasets in Size 256, 256

# %%
image_size256 = (256, 256)

# %%
ds_train256 = image_dataset_from_directory("/content/drive/MyDrive/Uni/DL/Project/datasets/datasets/train",
                                        labels=labels,
                                        image_size=image_size256,
                                        crop_to_aspect_ratio=crop_to_aspect_ratio,
                                        color_mode=color_mode,
                                        batch_size=batch_size,
                                        label_mode=label_mode,
                                        shuffle=shuffle,
                                        seed=seed
                                        )

ds_validation256 = image_dataset_from_directory("/content/drive/MyDrive/Uni/DL/Project/datasets/datasets/validation",
                                             labels=labels,
                                             image_size=image_size256,
                                             crop_to_aspect_ratio=crop_to_aspect_ratio,
                                             color_mode=color_mode,
                                             batch_size=batch_size,
                                             label_mode=label_mode,
                                             shuffle=shuffle,
                                             seed=seed
                                             )

ds_test256 = image_dataset_from_directory("/content/drive/MyDrive/Uni/DL/Project/datasets/datasets/test",
                                       labels=labels, 
                                       image_size=image_size256,
                                       crop_to_aspect_ratio=crop_to_aspect_ratio,
                                       color_mode=color_mode,
                                       batch_size=batch_size,
                                       label_mode=label_mode,
                                       shuffle=shuffle,
                                       seed=seed
                                       )
# Out:
# Found 1034 files belonging to 3 classes.
# Found 133 files belonging to 3 classes.
# Found 128 files belonging to 3 classes.

# %%
input_shape2 = tuple(iter(ds_train256).next()[0].shape[1:])

# %%
input_shape2
# Out:
# (256, 256, 3)

# %% [markdown]
# # Create Agumentation Layer

# %%
augmentation = Sequential([layers.RandomFlip(), 
                           layers.RandomRotation(factor=0.2), 
                           layers.RandomZoom(height_factor=0.1, width_factor=0.1),
                           layers.RandomContrast(factor=0.3),
                           layers.RandomBrightness(factor=0.3),
                           layers.RandomTranslation(height_factor=(-0.1, 0.1), width_factor=(-0.1, 0.1))], 
                           name="my_augmentation_pipeline")

# %% [markdown]
# ----------------------------------------------

# %% [markdown]
# # Function LeNet

# %%
def LeNet_builder(hp):
    cnn = Sequential([layers.Input((256, 256, 3)),                                  
                      # Data augmentation
                      augmentation,
                      # Data preprocessing
                      layers.Rescaling(1./255),
                      # 1st convLayer
                      layers.Conv2D(
                          filters=hp.Int('conv_1_num_filters', min_value=8, max_value=128, step=8),
                          kernel_size=hp.Choice('conv_1_kernel_size', values = [2,3,4,5,6,7,8]),
                          kernel_initializer=initializers.GlorotNormal(seed=42)
                          ),
                      layers.Activation(hp.Choice('1_activation', values=['relu', 'softmax', 'sigmoid'])),
                      layers.MaxPooling2D(pool_size=hp.Choice('1_pool_size', values = [2,3,4])),
                      # 2nd convLayer
                      layers.Conv2D(
                          filters=hp.Int('conv_2_num_filters', min_value=16, max_value=128, step=8),
                          kernel_size=hp.Choice('conv_2_kernel_size', values = [2,3,4,5,6,7,8]),
                          kernel_initializer=initializers.GlorotNormal(seed=42)
                          ),
                      layers.Activation(hp.Choice('2_activation', values=['relu', 'softmax', 'sigmoid'])),
                      layers.MaxPooling2D(pool_size=hp.Choice('2_pool_size', values = [2,3,4])),
                      # From a HxWxC cuboid to a (H*W*C) vector per image
                      layers.Flatten(),
                      # Classification 
                      layers.Dense(
                          units=3,
                          activation=hp.Choice('dense_activation', values=['relu', 'softmax', 'sigmoid']),
                          kernel_initializer=initializers.GlorotNormal(seed=42)
                          )
                      ], 
                  name="CNN-1"
                  )

    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    cnn.compile(loss="categorical_crossentropy",
    optimizer=hp.Choice('optimizer', values=['adam', 'rmsprop', 'sgd']),  
    metrics=[
            metrics.CategoricalAccuracy(name='categorical_accuracy'),
            metrics.AUC(name='AUROC')
          ]
      )
    
    K.set_value(cnn.optimizer.learning_rate, hp_learning_rate)

    return cnn

# %% [markdown]
# # Function AlexNet

# %%
def AlexnNet_builder(hp):
    cnn = Sequential([layers.Input((128,128,3)),                                          
                      # Data augmentation
                      augmentation,     
                      # Feature extraction
                      layers.BatchNormalization(),  
                      # P1
                      layers.Conv2D(filters=hp.Int('conv_1_num_filters', min_value=32, max_value=128, step=8),
                                    kernel_size=hp.Choice('conv_1_kernel_size', values = [4,5,6,7,8,9,10,11,12]),
                                    strides=hp.Choice('conv_1_strides', values = [3,4,5]),  
                                    kernel_initializer=initializers.GlorotNormal(seed=42)
                                    ),
                      layers.BatchNormalization(),  
                      layers.Activation(hp.Choice('1_activation', values=['relu', 'softmax', 'sigmoid'])),
                      layers.MaxPooling2D(pool_size=hp.Choice('1_pool_size', values = [2,3,4]),
                                          strides=hp.Choice('1_strides', values = [1,2,3])
                                          ),
                      # P2
                      layers.Conv2D(filters=hp.Int('conv_2_num_filters', min_value=128, max_value=256, step=8),
                                    kernel_size=hp.Choice('conv_2_kernel_size', values = [3,4,5,6,7]),
                                    padding=hp.Choice('conv_2_padding', values=['same']),
                                    kernel_initializer=initializers.GlorotNormal(seed=42)
                                    ),
                      layers.Activation(hp.Choice('2_activation', values=['relu', 'softmax', 'sigmoid'])),
                      layers.MaxPooling2D(pool_size=hp.Choice('2_pool_size', values = [2,3,4]),
                                          strides=hp.Choice('2_strides', values = [1,2,3])
                                          ),
                      # P3
                      layers.Conv2D(filters=hp.Int('conv_3_num_filters', min_value=128, max_value=256, step=8),
                                    kernel_size=hp.Choice('conv_3_kernel_size', values = [2,3,4,5]),
                                    padding=hp.Choice('conv_3_padding', values=['same']),
                                    kernel_initializer=initializers.GlorotNormal(seed=42)
                                    ),
                      layers.Activation(hp.Choice('3_activation', values=['relu', 'softmax', 'sigmoid'])),
                      layers.MaxPooling2D(pool_size=hp.Choice('3_pool_size', values = [2,3,4]),
                                          strides=hp.Choice('3_strides', values = [1,2,3])
                                          ),
                      # From a HxWxC cuboid to a (C) vector per image
                      layers.GlobalAveragePooling2D(),
                      # Classification 
                      layers.Dropout(hp.Choice('dropout', values = [0.2,0.3,0.4])),     
                      layers.Dense(units=3,
                                  activation=hp.Choice('dense_activation', values=['relu', 'softmax', 'sigmoid']),
                                  kernel_regularizer = regularizers.L2(l2=hp.Choice('dropout', values = [0.001, 0.0001, 0.00001])),
                                  bias_regularizer = regularizers.L2(hp.Choice('dropout', values = [0.001, 0.0001, 0.00001])),
                                  kernel_initializer=initializers.GlorotNormal(seed=42)
                                  )
                      ],
                      name="CNN-2"
                      )

    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    cnn.compile(loss="categorical_crossentropy",
    optimizer=hp.Choice('optimizer', values=['adam', 'rmsprop', 'sgd']),  
    metrics=[
            metrics.CategoricalAccuracy(name='categorical_accuracy'),
            metrics.AUC(name='AUROC')
          ]
      )
    
    K.set_value(cnn.optimizer.learning_rate, hp_learning_rate)
    

    return cnn

# %% [markdown]
# # Function Custom Architecture

# %%
def Custom_builder(hp):
    cnn = Sequential([# The input layer
                      layers.Input((128,128,3)),
                      # Data augmentation
                      augmentation,     
                      # Feature extraction
                      layers.BatchNormalization(),
                      layers.Conv2D(filters=hp.Int('conv_1_num_filters', min_value=32, max_value=128, step=8),
                                    kernel_size=hp.Choice('conv_1_kernel_size', values = [4,5,6,7,8,9,10,11,12]),
                                    strides=hp.Choice('conv_1_strides', values = [3,4,5]),  
                                    kernel_initializer=initializers.GlorotNormal(seed=42)
                                    ),
                      layers.BatchNormalization(),
                      layers.Activation(hp.Choice('1_activation', values=['relu', 'softmax', 'sigmoid'])),
                      layers.MaxPooling2D(pool_size=hp.Choice('1_pool_size', values = [2,3,4]),
                                           strides=hp.Choice('1_strides', values = [1,2,3])
                                           ),
                      layers.Conv2D(filters=hp.Int('conv_2_num_filters', min_value=128, max_value=256, step=8),
                                    kernel_size=hp.Choice('conv_2_kernel_size', values = [3,4,5,6,7]),
                                    padding=hp.Choice('conv_2_padding', values=['same']),
                                    kernel_initializer=initializers.GlorotNormal(seed=42)
                                    ),
                      layers.BatchNormalization(),
                      layers.Activation(hp.Choice('2_activation', values=['relu', 'softmax', 'sigmoid'])),
                      layers.MaxPooling2D(pool_size=hp.Choice('2_pool_size', values = [2,3,4]),
                                          strides=hp.Choice('2_strides', values = [1,2,3])
                                          ),
                      layers.Conv2D(filters=hp.Int('conv_3_num_filters', min_value=128, max_value=256, step=8),
                                    kernel_size=hp.Choice('conv_3_kernel_size', values = [3,4,5,6,7]),
                                    padding=hp.Choice('conv_3_padding', values=['same']),
                                    kernel_initializer=initializers.GlorotNormal(seed=42)
                                    ),
                      layers.BatchNormalization(),
                      layers.Activation(hp.Choice('3_activation', values=['relu', 'softmax', 'sigmoid'])),
                      layers.MaxPooling2D(pool_size=hp.Choice('3_pool_size', values = [2,3,4]),
                                          strides=hp.Choice('3_strides', values = [1,2,3])
                                          ),
                      layers.GlobalMaxPooling2D(),
                      layers.Dropout(hp.Choice('dropout', values = [0.2,0.3,0.4])),
                      # Classification
                      layers.Dense(
                           units=3,
                           activation=hp.Choice('dense_activation', values=['relu', 'softmax', 'sigmoid']),
                           kernel_initializer=initializers.GlorotNormal(seed=42)
                           )
                      ],
                     name="CNN-2"
                     )

    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    cnn.compile(loss="categorical_crossentropy",
    optimizer=hp.Choice('optimizer', values=['adam', 'rmsprop', 'sgd']),  
    metrics=[
            metrics.CategoricalAccuracy(name='categorical_accuracy'),
            metrics.AUC(name='AUROC')
          ]
      )
    
    K.set_value(cnn.optimizer.learning_rate, hp_learning_rate)

    return cnn

# %% [markdown]
# # Hyperparameter Search

# %%
tuner = kt.Hyperband(
    Custom_builder,
    objective='val_categorical_accuracy',
    max_epochs=100,
    factor=3,
    directory='Custom_128',
    project_name='Custom_128',
    overwrite=True)

# %%
stop_early = EarlyStopping(monitor='val_categorical_accuracy', patience=10)

# %%
tuner.search(ds_train, validation_data=ds_validation, epochs=100, callbacks=[stop_early])
# Out:
# Trial 232 Complete [00h 01m 00s]
# val_categorical_accuracy: 0.8571428656578064
#
# Best val_categorical_accuracy So Far: 0.969924807548523
# Total elapsed time: 00h 51m 22s

# %%
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

# %%
model = tuner.hypermodel.build(best_hps)
history = model.fit(ds_train, epochs=100, validation_data=ds_validation, callbacks=[stop_early])

val_acc_per_epoch = history.history['val_categorical_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/100
# 65/65 [==============================] - 4s 19ms/step - loss: 1.0379 - categorical_accuracy: 0.5213 - AUROC: 0.7101 - val_loss: 1.0979 - val_categorical_accuracy: 0.3684 - val_AUROC: 0.5044
# Epoch 2/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.9204 - categorical_accuracy: 0.6054 - AUROC: 0.7822 - val_loss: 1.0967 - val_categorical_accuracy: 0.3383 - val_AUROC: 0.5458
# Epoch 3/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.8318 - categorical_accuracy: 0.6364 - AUROC: 0.8152 - val_loss: 1.0949 - val_categorical_accuracy: 0.3383 - val_AUROC: 0.5676
# Epoch 4/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.8127 - categorical_accuracy: 0.6393 - AUROC: 0.8201 - val_loss: 1.0719 - val_categorical_accuracy: 0.4812 - val_AUROC: 0.6973
# Epoch 5/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.7308 - categorical_accuracy: 0.6963 - AUROC: 0.8616 - val_loss: 1.0576 - val_categorical_accuracy: 0.5038 - val_AUROC: 0.7581
# Epoch 6/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.6850 - categorical_accuracy: 0.7157 - AUROC: 0.8777 - val_loss: 0.9592 - val_categorical_accuracy: 0.7519 - val_AUROC: 0.8715
# Epoch 7/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.6173 - categorical_accuracy: 0.7476 - AUROC: 0.9002 - val_loss: 0.7885 - val_categorical_accuracy: 0.6466 - val_AUROC: 0.8599
# Epoch 8/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.6208 - categorical_accuracy: 0.7485 - AUROC: 0.8989 - val_loss: 0.6267 - val_categorical_accuracy: 0.8045 - val_AUROC: 0.9240
# Epoch 9/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.5692 - categorical_accuracy: 0.7776 - AUROC: 0.9165 - val_loss: 0.5094 - val_categorical_accuracy: 0.7895 - val_AUROC: 0.9304
# Epoch 10/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.5543 - categorical_accuracy: 0.7718 - AUROC: 0.9199 - val_loss: 0.5116 - val_categorical_accuracy: 0.7669 - val_AUROC: 0.9278
# Epoch 11/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.5216 - categorical_accuracy: 0.7979 - AUROC: 0.9298 - val_loss: 0.4116 - val_categorical_accuracy: 0.8797 - val_AUROC: 0.9566
# Epoch 12/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.5263 - categorical_accuracy: 0.8017 - AUROC: 0.9280 - val_loss: 0.3535 - val_categorical_accuracy: 0.8797 - val_AUROC: 0.9713
# Epoch 13/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.5015 - categorical_accuracy: 0.7969 - AUROC: 0.9334 - val_loss: 0.4598 - val_categorical_accuracy: 0.8271 - val_AUROC: 0.9446
# Epoch 14/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4760 - categorical_accuracy: 0.8095 - AUROC: 0.9407 - val_loss: 0.2846 - val_categorical_accuracy: 0.8947 - val_AUROC: 0.9785
# Epoch 15/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4727 - categorical_accuracy: 0.8133 - AUROC: 0.9410 - val_loss: 0.4469 - val_categorical_accuracy: 0.8421 - val_AUROC: 0.9508
# Epoch 16/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.5204 - categorical_accuracy: 0.7901 - AUROC: 0.9273 - val_loss: 0.4408 - val_categorical_accuracy: 0.8271 - val_AUROC: 0.9480
# Epoch 17/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4531 - categorical_accuracy: 0.8095 - AUROC: 0.9458 - val_loss: 0.4377 - val_categorical_accuracy: 0.8421 - val_AUROC: 0.9471
# Epoch 18/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.4366 - categorical_accuracy: 0.8298 - AUROC: 0.9495 - val_loss: 0.4073 - val_categorical_accuracy: 0.8421 - val_AUROC: 0.9540
# Epoch 19/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.4522 - categorical_accuracy: 0.8124 - AUROC: 0.9458 - val_loss: 0.3284 - val_categorical_accuracy: 0.8647 - val_AUROC: 0.9717
# Epoch 20/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.4352 - categorical_accuracy: 0.8221 - AUROC: 0.9501 - val_loss: 0.3828 - val_categorical_accuracy: 0.8797 - val_AUROC: 0.9624
# Epoch 21/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4252 - categorical_accuracy: 0.8346 - AUROC: 0.9522 - val_loss: 0.4180 - val_categorical_accuracy: 0.8421 - val_AUROC: 0.9549
# Epoch 22/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4359 - categorical_accuracy: 0.8279 - AUROC: 0.9499 - val_loss: 0.3358 - val_categorical_accuracy: 0.8797 - val_AUROC: 0.9697
# Epoch 23/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4059 - categorical_accuracy: 0.8375 - AUROC: 0.9554 - val_loss: 0.2191 - val_categorical_accuracy: 0.9173 - val_AUROC: 0.9873
# Epoch 24/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4002 - categorical_accuracy: 0.8404 - AUROC: 0.9565 - val_loss: 0.3102 - val_categorical_accuracy: 0.9023 - val_AUROC: 0.9756
# Epoch 25/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4042 - categorical_accuracy: 0.8279 - AUROC: 0.9560 - val_loss: 0.4039 - val_categorical_accuracy: 0.8271 - val_AUROC: 0.9588
# Epoch 26/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4181 - categorical_accuracy: 0.8317 - AUROC: 0.9530 - val_loss: 0.3161 - val_categorical_accuracy: 0.8797 - val_AUROC: 0.9729
# Epoch 27/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3427 - categorical_accuracy: 0.8636 - AUROC: 0.9691 - val_loss: 0.2400 - val_categorical_accuracy: 0.9248 - val_AUROC: 0.9827
# Epoch 28/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3673 - categorical_accuracy: 0.8511 - AUROC: 0.9635 - val_loss: 0.1811 - val_categorical_accuracy: 0.9173 - val_AUROC: 0.9912
# Epoch 29/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.3362 - categorical_accuracy: 0.8627 - AUROC: 0.9699 - val_loss: 0.2007 - val_categorical_accuracy: 0.9248 - val_AUROC: 0.9896
# Epoch 30/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.3773 - categorical_accuracy: 0.8453 - AUROC: 0.9618 - val_loss: 0.1299 - val_categorical_accuracy: 0.9624 - val_AUROC: 0.9954
# Epoch 31/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3915 - categorical_accuracy: 0.8453 - AUROC: 0.9585 - val_loss: 0.2773 - val_categorical_accuracy: 0.8947 - val_AUROC: 0.9795
# Epoch 32/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3601 - categorical_accuracy: 0.8511 - AUROC: 0.9648 - val_loss: 0.1919 - val_categorical_accuracy: 0.9624 - val_AUROC: 0.9908
# Epoch 33/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3999 - categorical_accuracy: 0.8424 - AUROC: 0.9567 - val_loss: 0.2258 - val_categorical_accuracy: 0.9248 - val_AUROC: 0.9862
# Epoch 34/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3761 - categorical_accuracy: 0.8569 - AUROC: 0.9618 - val_loss: 0.2638 - val_categorical_accuracy: 0.9098 - val_AUROC: 0.9790
# Epoch 35/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3518 - categorical_accuracy: 0.8578 - AUROC: 0.9661 - val_loss: 0.1972 - val_categorical_accuracy: 0.9398 - val_AUROC: 0.9892
# Epoch 36/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3385 - categorical_accuracy: 0.8685 - AUROC: 0.9689 - val_loss: 0.1859 - val_categorical_accuracy: 0.9323 - val_AUROC: 0.9911
# Epoch 37/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3529 - categorical_accuracy: 0.8685 - AUROC: 0.9658 - val_loss: 0.2240 - val_categorical_accuracy: 0.9098 - val_AUROC: 0.9866
# Epoch 38/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3601 - categorical_accuracy: 0.8598 - AUROC: 0.9642 - val_loss: 0.1980 - val_categorical_accuracy: 0.8947 - val_AUROC: 0.9898
# Epoch 39/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.3462 - categorical_accuracy: 0.8656 - AUROC: 0.9675 - val_loss: 0.2345 - val_categorical_accuracy: 0.9398 - val_AUROC: 0.9841
# Epoch 40/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.3281 - categorical_accuracy: 0.8781 - AUROC: 0.9711 - val_loss: 0.2239 - val_categorical_accuracy: 0.8947 - val_AUROC: 0.9872
# Best epoch: 30

# %%
best_hps.values
# Out:
# {'conv_1_num_filters': 64,
#  'conv_1_kernel_size': 4,
#  'conv_1_strides': 3,
#  '1_activation': 'relu',
#  '1_pool_size': 3,
#  '1_strides': 3,
#  'conv_2_num_filters': 224,
#  'conv_2_kernel_size': 5,
#  'conv_2_padding': 'same',
#  '2_activation': 'softmax',
#  '2_pool_size': 4,
#  '2_strides': 2,
#  'conv_3_num_filters': 248,
#  'conv_3_kernel_size': 4,
#  'conv_3_padding': 'same',
#  '3_activation': 'softmax',
#  '3_pool_size': 4,
#  '3_strides': 1,
#  'dropout': 0.3,
#  'dense_activation': 'softmax',
#  'learning_rate': 0.001,
#  'optimizer': 'rmsprop',
#  'tuner/epochs': 100,
#  'tuner/initial_epoch': 34,
#  'tuner/bracket': 2,
#  'tuner/round': 2,
#  'tuner/trial_id': '0206'}

# %%
best_epoch
# Out:
# 30

# %%
stop_early_final = EarlyStopping(monitor='val_categorical_accuracy', patience=15)

# %%
hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
history = hypermodel.fit(ds_train, epochs=100, validation_data=ds_validation, callbacks=[stop_early_final])
# Out:
# Epoch 1/100
# 65/65 [==============================] - 4s 19ms/step - loss: 1.0401 - categorical_accuracy: 0.4710 - AUROC: 0.6725 - val_loss: 1.0977 - val_categorical_accuracy: 0.3383 - val_AUROC: 0.5353
# Epoch 2/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.9350 - categorical_accuracy: 0.5996 - AUROC: 0.7739 - val_loss: 1.0958 - val_categorical_accuracy: 0.3383 - val_AUROC: 0.5667
# Epoch 3/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.8193 - categorical_accuracy: 0.6586 - AUROC: 0.8261 - val_loss: 1.0923 - val_categorical_accuracy: 0.3383 - val_AUROC: 0.6023
# Epoch 4/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.7906 - categorical_accuracy: 0.6431 - AUROC: 0.8308 - val_loss: 1.0770 - val_categorical_accuracy: 0.3759 - val_AUROC: 0.6906
# Epoch 5/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.7424 - categorical_accuracy: 0.6857 - AUROC: 0.8549 - val_loss: 1.0582 - val_categorical_accuracy: 0.4135 - val_AUROC: 0.7258
# Epoch 6/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.6975 - categorical_accuracy: 0.6992 - AUROC: 0.8714 - val_loss: 0.8933 - val_categorical_accuracy: 0.7519 - val_AUROC: 0.8984
# Epoch 7/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.6750 - categorical_accuracy: 0.7166 - AUROC: 0.8792 - val_loss: 0.8439 - val_categorical_accuracy: 0.6391 - val_AUROC: 0.8611
# Epoch 8/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.6127 - categorical_accuracy: 0.7398 - AUROC: 0.9011 - val_loss: 0.5610 - val_categorical_accuracy: 0.8120 - val_AUROC: 0.9436
# Epoch 9/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.6239 - categorical_accuracy: 0.7389 - AUROC: 0.8968 - val_loss: 0.5771 - val_categorical_accuracy: 0.8120 - val_AUROC: 0.9097
# Epoch 10/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.5672 - categorical_accuracy: 0.7669 - AUROC: 0.9152 - val_loss: 0.5350 - val_categorical_accuracy: 0.7293 - val_AUROC: 0.9213
# Epoch 11/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.5571 - categorical_accuracy: 0.7737 - AUROC: 0.9192 - val_loss: 0.5045 - val_categorical_accuracy: 0.8271 - val_AUROC: 0.9321
# Epoch 12/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.5304 - categorical_accuracy: 0.7969 - AUROC: 0.9275 - val_loss: 0.4749 - val_categorical_accuracy: 0.7895 - val_AUROC: 0.9386
# Epoch 13/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4925 - categorical_accuracy: 0.7979 - AUROC: 0.9387 - val_loss: 0.3886 - val_categorical_accuracy: 0.8496 - val_AUROC: 0.9604
# Epoch 14/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4714 - categorical_accuracy: 0.8124 - AUROC: 0.9416 - val_loss: 0.4423 - val_categorical_accuracy: 0.8120 - val_AUROC: 0.9491
# Epoch 15/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.5060 - categorical_accuracy: 0.7882 - AUROC: 0.9304 - val_loss: 0.2750 - val_categorical_accuracy: 0.9098 - val_AUROC: 0.9819
# Epoch 16/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4638 - categorical_accuracy: 0.8259 - AUROC: 0.9431 - val_loss: 0.3350 - val_categorical_accuracy: 0.8797 - val_AUROC: 0.9683
# Epoch 17/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.4590 - categorical_accuracy: 0.8172 - AUROC: 0.9443 - val_loss: 0.2692 - val_categorical_accuracy: 0.8797 - val_AUROC: 0.9816
# Epoch 18/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.4555 - categorical_accuracy: 0.8230 - AUROC: 0.9449 - val_loss: 0.5277 - val_categorical_accuracy: 0.7970 - val_AUROC: 0.9334
# Epoch 19/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4909 - categorical_accuracy: 0.8037 - AUROC: 0.9362 - val_loss: 0.2529 - val_categorical_accuracy: 0.9098 - val_AUROC: 0.9839
# Epoch 20/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4573 - categorical_accuracy: 0.8327 - AUROC: 0.9444 - val_loss: 0.5322 - val_categorical_accuracy: 0.8195 - val_AUROC: 0.9337
# Epoch 21/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4153 - categorical_accuracy: 0.8288 - AUROC: 0.9540 - val_loss: 0.4402 - val_categorical_accuracy: 0.8571 - val_AUROC: 0.9465
# Epoch 22/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4007 - categorical_accuracy: 0.8482 - AUROC: 0.9572 - val_loss: 0.2941 - val_categorical_accuracy: 0.8872 - val_AUROC: 0.9777
# Epoch 23/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4277 - categorical_accuracy: 0.8269 - AUROC: 0.9503 - val_loss: 0.3546 - val_categorical_accuracy: 0.8271 - val_AUROC: 0.9677
# Epoch 24/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4047 - categorical_accuracy: 0.8395 - AUROC: 0.9562 - val_loss: 0.2896 - val_categorical_accuracy: 0.8872 - val_AUROC: 0.9776
# Epoch 25/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.4180 - categorical_accuracy: 0.8443 - AUROC: 0.9526 - val_loss: 0.1908 - val_categorical_accuracy: 0.9173 - val_AUROC: 0.9912
# Epoch 26/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3810 - categorical_accuracy: 0.8569 - AUROC: 0.9611 - val_loss: 0.2139 - val_categorical_accuracy: 0.9023 - val_AUROC: 0.9887
# Epoch 27/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.3928 - categorical_accuracy: 0.8453 - AUROC: 0.9580 - val_loss: 0.2423 - val_categorical_accuracy: 0.8797 - val_AUROC: 0.9845
# Epoch 28/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.3806 - categorical_accuracy: 0.8366 - AUROC: 0.9613 - val_loss: 0.1971 - val_categorical_accuracy: 0.9323 - val_AUROC: 0.9905
# Epoch 29/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.3975 - categorical_accuracy: 0.8414 - AUROC: 0.9572 - val_loss: 0.2645 - val_categorical_accuracy: 0.8722 - val_AUROC: 0.9808
# Epoch 30/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3767 - categorical_accuracy: 0.8559 - AUROC: 0.9614 - val_loss: 0.1839 - val_categorical_accuracy: 0.9173 - val_AUROC: 0.9909
# Epoch 31/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3722 - categorical_accuracy: 0.8472 - AUROC: 0.9619 - val_loss: 0.1952 - val_categorical_accuracy: 0.9323 - val_AUROC: 0.9911
# Epoch 32/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3808 - categorical_accuracy: 0.8540 - AUROC: 0.9610 - val_loss: 0.3732 - val_categorical_accuracy: 0.8496 - val_AUROC: 0.9623
# Epoch 33/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3351 - categorical_accuracy: 0.8723 - AUROC: 0.9700 - val_loss: 0.2446 - val_categorical_accuracy: 0.9023 - val_AUROC: 0.9855
# Epoch 34/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3405 - categorical_accuracy: 0.8636 - AUROC: 0.9690 - val_loss: 0.1612 - val_categorical_accuracy: 0.9398 - val_AUROC: 0.9930
# Epoch 35/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3807 - categorical_accuracy: 0.8636 - AUROC: 0.9616 - val_loss: 0.1638 - val_categorical_accuracy: 0.9398 - val_AUROC: 0.9927
# Epoch 36/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3491 - categorical_accuracy: 0.8656 - AUROC: 0.9669 - val_loss: 0.2184 - val_categorical_accuracy: 0.9098 - val_AUROC: 0.9874
# Epoch 37/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3382 - categorical_accuracy: 0.8627 - AUROC: 0.9695 - val_loss: 0.1987 - val_categorical_accuracy: 0.9173 - val_AUROC: 0.9897
# Epoch 38/100
# 65/65 [==============================] - 1s 18ms/step - loss: 0.3541 - categorical_accuracy: 0.8772 - AUROC: 0.9654 - val_loss: 0.1717 - val_categorical_accuracy: 0.9323 - val_AUROC: 0.9929
# Epoch 39/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.3384 - categorical_accuracy: 0.8839 - AUROC: 0.9684 - val_loss: 0.2690 - val_categorical_accuracy: 0.9023 - val_AUROC: 0.9807
# Epoch 40/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3172 - categorical_accuracy: 0.8627 - AUROC: 0.9715 - val_loss: 0.1543 - val_categorical_accuracy: 0.9398 - val_AUROC: 0.9943
# Epoch 41/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.3101 - categorical_accuracy: 0.8820 - AUROC: 0.9740 - val_loss: 0.1929 - val_categorical_accuracy: 0.9398 - val_AUROC: 0.9899
# Epoch 42/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3053 - categorical_accuracy: 0.8810 - AUROC: 0.9742 - val_loss: 0.1955 - val_categorical_accuracy: 0.9248 - val_AUROC: 0.9899
# Epoch 43/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3204 - categorical_accuracy: 0.8723 - AUROC: 0.9719 - val_loss: 0.2800 - val_categorical_accuracy: 0.8872 - val_AUROC: 0.9803
# Epoch 44/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3353 - categorical_accuracy: 0.8743 - AUROC: 0.9688 - val_loss: 0.1973 - val_categorical_accuracy: 0.9023 - val_AUROC: 0.9904
# Epoch 45/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.2965 - categorical_accuracy: 0.8820 - AUROC: 0.9756 - val_loss: 0.1496 - val_categorical_accuracy: 0.9323 - val_AUROC: 0.9943
# Epoch 46/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3363 - categorical_accuracy: 0.8665 - AUROC: 0.9687 - val_loss: 0.1822 - val_categorical_accuracy: 0.9248 - val_AUROC: 0.9909
# Epoch 47/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3241 - categorical_accuracy: 0.8791 - AUROC: 0.9708 - val_loss: 0.2017 - val_categorical_accuracy: 0.9323 - val_AUROC: 0.9896
# Epoch 48/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.3186 - categorical_accuracy: 0.8752 - AUROC: 0.9726 - val_loss: 0.1764 - val_categorical_accuracy: 0.9248 - val_AUROC: 0.9921
# Epoch 49/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.3065 - categorical_accuracy: 0.8839 - AUROC: 0.9747 - val_loss: 0.1714 - val_categorical_accuracy: 0.9549 - val_AUROC: 0.9912
# Epoch 50/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.3146 - categorical_accuracy: 0.8752 - AUROC: 0.9728 - val_loss: 0.1460 - val_categorical_accuracy: 0.9549 - val_AUROC: 0.9948
# Epoch 51/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3017 - categorical_accuracy: 0.8791 - AUROC: 0.9750 - val_loss: 0.3282 - val_categorical_accuracy: 0.8647 - val_AUROC: 0.9729
# Epoch 52/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.2957 - categorical_accuracy: 0.8762 - AUROC: 0.9758 - val_loss: 0.1534 - val_categorical_accuracy: 0.9398 - val_AUROC: 0.9938
# Epoch 53/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.3003 - categorical_accuracy: 0.8917 - AUROC: 0.9747 - val_loss: 0.1998 - val_categorical_accuracy: 0.9323 - val_AUROC: 0.9888
# Epoch 54/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.2788 - categorical_accuracy: 0.8849 - AUROC: 0.9784 - val_loss: 0.2215 - val_categorical_accuracy: 0.9248 - val_AUROC: 0.9859
# Epoch 55/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.2833 - categorical_accuracy: 0.9023 - AUROC: 0.9777 - val_loss: 0.1351 - val_categorical_accuracy: 0.9398 - val_AUROC: 0.9939
# Epoch 56/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.2588 - categorical_accuracy: 0.8936 - AUROC: 0.9816 - val_loss: 0.1861 - val_categorical_accuracy: 0.9023 - val_AUROC: 0.9887
# Epoch 57/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.2715 - categorical_accuracy: 0.8956 - AUROC: 0.9792 - val_loss: 0.1364 - val_categorical_accuracy: 0.9323 - val_AUROC: 0.9951
# Epoch 58/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.2922 - categorical_accuracy: 0.8849 - AUROC: 0.9761 - val_loss: 0.1147 - val_categorical_accuracy: 0.9549 - val_AUROC: 0.9965
# Epoch 59/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.2879 - categorical_accuracy: 0.8926 - AUROC: 0.9770 - val_loss: 0.1928 - val_categorical_accuracy: 0.9323 - val_AUROC: 0.9911
# Epoch 60/100
# 65/65 [==============================] - 1s 17ms/step - loss: 0.2618 - categorical_accuracy: 0.9014 - AUROC: 0.9809 - val_loss: 0.1399 - val_categorical_accuracy: 0.9474 - val_AUROC: 0.9948
# Epoch 61/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.2800 - categorical_accuracy: 0.8820 - AUROC: 0.9778 - val_loss: 0.2139 - val_categorical_accuracy: 0.9098 - val_AUROC: 0.9889
# Epoch 62/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.2997 - categorical_accuracy: 0.8839 - AUROC: 0.9757 - val_loss: 0.1225 - val_categorical_accuracy: 0.9474 - val_AUROC: 0.9972
# Epoch 63/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.2462 - categorical_accuracy: 0.9033 - AUROC: 0.9824 - val_loss: 0.2219 - val_categorical_accuracy: 0.9323 - val_AUROC: 0.9863
# Epoch 64/100
# 65/65 [==============================] - 1s 16ms/step - loss: 0.2734 - categorical_accuracy: 0.8985 - AUROC: 0.9789 - val_loss: 0.1368 - val_categorical_accuracy: 0.9248 - val_AUROC: 0.9953

# %%
df_hist = pd.DataFrame.from_dict(history.history)
df_hist["Epoch"] = np.arange(1, len(df_hist) + 1, 1)
# Plot learning curves
secondary_y = ["categorical_accuracy", "val_categorical_accuracy", "AUROC", "val_AUROC"] 
ax = df_hist.plot(x="Epoch", y=['loss', 'val_loss'] + secondary_y,
                  secondary_y = secondary_y, 
                  kind="line", figsize=(6, 3), grid=True, legend=True,
                  ylabel="Categorical cross-entropy", 
                  xlabel="Epoch", title="Learning curves", 
                  style=[".--", ".-"]*3,
                  color=['darkred', 'indianred', "darkblue", "royalblue", "seagreen", "darkseagreen"], 
                         alpha=0.75, fontsize=10)
ax.right_ax.set_ylabel("Categorical Accuracy")
ax.right_ax.legend(loc=(1.15, 0.65), framealpha=1.0)
ax.right_ax.set_ylim(0.45, 1.05)
ax.legend(loc=(1.15, 0.40), framealpha=1.0)
plt.show()

# %%
eval_result = hypermodel.evaluate(ds_test)
print("[test loss, categorical_accuracy, test accuracy]:", eval_result)
# Out:
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2236 - categorical_accuracy: 0.9141 - AUROC: 0.9868
# [test loss, categorical_accuracy, test accuracy]: [0.22362086176872253, 0.9140625, 0.9868011474609375]

# %%
hypermodel.summary()
# Out:
# Model: "CNN-2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  my_augmentation_pipeline (S  (None, None, None, 3)    0
#  equential)
#
#  batch_normalization_8 (Batc  (None, 128, 128, 3)      12
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 42, 42, 64)        3136
#
#  batch_normalization_9 (Batc  (None, 42, 42, 64)       256
#  hNormalization)
#
#  activation_6 (Activation)   (None, 42, 42, 64)        0
#
#  max_pooling2d_6 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 14, 14, 224)       358624
#
#  batch_normalization_10 (Bat  (None, 14, 14, 224)      896
#  chNormalization)
#
#  activation_7 (Activation)   (None, 14, 14, 224)       0
#
#  max_pooling2d_7 (MaxPooling  (None, 6, 6, 224)        0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 6, 6, 248)         889080
#
#  batch_normalization_11 (Bat  (None, 6, 6, 248)        992
#  chNormalization)
#
#  activation_8 (Activation)   (None, 6, 6, 248)         0
#
#  max_pooling2d_8 (MaxPooling  (None, 3, 3, 248)        0
#  2D)
#
#  global_max_pooling2d_2 (Glo  (None, 248)              0
#  balMaxPooling2D)
#
#  dropout_2 (Dropout)         (None, 248)               0
#
#  dense_2 (Dense)             (None, 3)                 747
#
# =================================================================
# Total params: 1,253,743
# Trainable params: 1,252,665
# Non-trainable params: 1,078
# _________________________________________________________________

# %%
# %cd /content/drive/MyDrive
# %mkdir -p saved_models
hypermodel.save('saved_models/Custom_128')
# Out:
# /content/drive/MyDrive
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.

# %%
loaded_model = load_model("saved_models/Custom_128")

# %%
eval_result_loaded = loaded_model.evaluate(ds_test)
print("[test loss, categorical_accuracy, test accuracy]:", eval_result_loaded)
# Out:
# 8/8 [==============================] - 0s 5ms/step - loss: 0.2236 - categorical_accuracy: 0.9141 - AUROC: 0.9868
# [test loss, categorical_accuracy, test accuracy]: [0.22362086176872253, 0.9140625, 0.9868011474609375]

# %% [markdown]
# # Outcomes

# %% [markdown]
# ### LeNet Architecture with (128, 128)
# ```
# image_size = (128, 128)
# crop_to_aspect_ratio = False
# labels='inferred'
# color_mode="rgb"
# batch_size=16
# label_mode="categorical"
# shuffle=True
# seed=42
# ```
# The HPS gave us:
# ```
# {'conv_1_num_filters': 16,
#  'conv_1_kernel_size': 6,
#  '1_activation': 'relu',
#  '1_pool_size': 2,
#  'conv_2_num_filters': 56,
#  'conv_2_kernel_size': 6,
#  '2_activation': 'relu',
#  '2_pool_size': 4,
#  'dense_activation': 'sigmoid',
#  'learning_rate': 0.0001,
#  'optimizer': 'rmsprop',
#  'tuner/epochs': 100,
#  'tuner/initial_epoch': 34,
#  'tuner/bracket': 3,
#  'tuner/round': 3,
#  'tuner/trial_id': '0206'}
# ```
#
# ![grafik.png](data:image/png;base64,...)

# %% [markdown]
# #### Training Curve LeNet
#
# ![grafik.png](data:image/png;base64,...)

# %% [markdown]
# #### LeNet evaluation on test dataset

# %% [markdown]
# ```
# [test loss, categorical_accuracy, test accuracy]: [0.3569413125514984, 0.875, 0.91448974609375]
# ```

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### LeNet Architecture with (256, 256)
# ```
# image_size256 = (256, 256)
# crop_to_aspect_ratio = False
# labels='inferred'
# color_mode="rgb"
# batch_size=16
# label_mode="categorical"
# shuffle=True
# seed=42
# ```
# The HPS gave us:
# ```
# {'conv_1_num_filters': 128,
#  'conv_1_kernel_size': 7,
#  '1_activation': 'relu',
#  '1_pool_size': 4,
#  'conv_2_num_filters': 128,
#  'conv_2_kernel_size': 8,
#  '2_activation': 'relu',
#  '2_pool_size': 4,
#  'dense_activation': 'sigmoid',
#  'learning_rate': 0.001,
#  'optimizer': 'sgd',
#  'tuner/epochs': 100,
#  'tuner/initial_epoch': 34,
#  'tuner/bracket': 4,
#  'tuner/round': 4,
#  'tuner/trial_id': '0142'}
# ```
# ![grafik.png](data:image/png;base64,...)

# %% [markdown]
# #### Training Curve LeNet
# ![grafik.png](data:image/png;base64,...)

# %% [markdown]
# #### LeNet evaluation on test dataset

# %% [markdown]
# ```
# [test loss, categorical_accuracy, test accuracy]: [0.40438395738601685, 0.859375, 0.935699462890625]
# ```

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### AlexNet Architecture with (128, 128)
# ```
# image_size256 = (128, 128)
# crop_to_aspect_ratio = False
# labels='inferred'
# color_mode="rgb"
# batch_size=16
# label_mode="categorical"
# shuffle=True
# seed=42
# ```
# The HPS gave us:
# ```
# {'conv_1_num_filters': 96,
#  'conv_1_kernel_size': 9,
#  'conv_1_strides': 5,
#  '1_activation': 'relu',
#  '1_pool_size': 3,
#  '1_strides': 2,
#  'conv_2_num_filters': 232,
#  'conv_2_kernel_size': 7,
#  'conv_2_padding': 'same',
#  '2_activation': 'sigmoid',
#  '2_pool_size': 2,
#  '2_strides': 2,
#  'conv_3_num_filters': 232,
#  'conv_3_kernel_size': 3,
#  'conv_3_padding': 'same',
#  '3_activation': 'relu',
#  '3_pool_size': 3,
#  '3_strides': 3,
#  'dropout': 0.4,
#  'dense_activation': 'softmax',
#  'learning_rate': 0.0001,
#  'optimizer': 'adam',
#  'tuner/epochs': 100,
#  'tuner/initial_epoch': 34,
#  'tuner/bracket': 1,
#  'tuner/round': 1,
#  'tuner/trial_id': '0210'}
# ```
#
# ![grafik.png](data:image/png;base64,...)

# %% [markdown]
# #### Training Curve AlexNet
# ![grafik.png](data:image/png;base64,...)

# %% [markdown]
# #### AlexNet evaluation on test dataset

# %% [markdown]
# ```
# [test loss, categorical_accuracy, test accuracy]: [0.3871889114379883, 0.8828125, 0.9662628173828125]
# ```

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### AlexNet Architecture with (256, 256)
# ```
# image_size256 = (256, 256)
# crop_to_aspect_ratio = False
# labels='inferred'
# color_mode="rgb"
# batch_size=16
# label_mode="categorical"
# shuffle=True
# seed=42
# ```
# The HPS gave us:
# ```
# {'conv_1_num_filters': 48,
#  'conv_1_kernel_size': 11,
#  'conv_1_strides': 3,
#  '1_activation': 'sigmoid',
#  '1_pool_size': 4,
#  '1_strides': 3,
#  'conv_2_num_filters': 160,
#  'conv_2_kernel_size': 4,
#  'conv_2_padding': 'valid',
#  '2_activation': 'relu',
#  '2_pool_size': 2,
#  '2_strides': 3,
#  'conv_3_num_filters': 240,
#  'conv_3_kernel_size': 2,
#  'conv_3_padding': 'same',
#  '3_activation': 'relu',
#  '3_pool_size': 4,
#  '3_strides': 1,
#  'dropout': 0.2,
#  'dense_activation': 'sigmoid',
#  'learning_rate': 0.001,
#  'optimizer': 'rmsprop',
#  'tuner/epochs': 100,
#  'tuner/initial_epoch': 34,
#  'tuner/bracket': 3,
#  'tuner/round': 3,
#  'tuner/trial_id': '0191'}
# ```
# ![grafik.png](data:image/png;base64,...)

# %% [markdown]
# #### Training Curve AlexNet
#
# ![grafik.png](data:image/png;base64,...)

# %% [markdown]
# #### AlexNet evaluation on test dataset

# %% [markdown]
# ```
# [test loss, categorical_accuracy, test accuracy]: [0.5259636640548706, 0.7890625, 0.923492431640625]
# ```

# %% [markdown]
# ---
#
# ---

# %% [markdown]
# ### Custom Architecture with (128, 128)
#
#
# ```
# image_size = (128, 128)
# crop_to_aspect_ratio = False
# labels='inferred'
# color_mode="rgb"
# batch_size=16
# label_mode="categorical"
# shuffle=True
# seed=42
#
# ```
# The HPS gave us:
#
#
#
# ```
#  {'conv_1_num_filters': 64,
#  'conv_1_kernel_size': 4,
#  'conv_1_strides': 3,
#  '1_activation': 'relu',
#  '1_pool_size': 3,
#  '1_strides': 3,
#  'conv_2_num_filters': 224,
#  'conv_2_kernel_size': 5,
#  'conv_2_padding': 'same',
#  '2_activation': 'softmax',
#  '2_pool_size': 4,
#  '2_strides': 2,
#  'conv_3_num_filters': 248,
#  'conv_3_kernel_size': 4,
#  'conv_3_padding': 'same',
#  '3_activation': 'softmax',
#  '3_pool_size': 4,
#  '3_strides': 1,
#  'dropout': 0.3,
#  'dense_activation': 'softmax',
#  'learning_rate': 0.001,
#  'optimizer': 'rmsprop',
#  'tuner/epochs': 100,
#  'tuner/initial_epoch': 34,
#  'tuner/bracket': 2,
#  'tuner/round': 2,
#  'tuner/trial_id': '0206'}
# ```
# ![grafik.png](data:image/png;base64,...)

# %% [markdown]
# #### Training Curve Custom Architecture
# ![grafik.png](data:image/png;base64,...)

# %% [markdown]
# #### Custom Architecture evaluation on test dataset

# %% [markdown]
# ```
# [test loss, categorical_accuracy, test accuracy]: [0.22362086176872253, 0.9140625, 0.9868011474609375]
# ```

# %% [markdown]
# ### Custom Architecture with (256, 256)
#
# ```
# image_size = (256, 256)
# crop_to_aspect_ratio = False
# labels='inferred'
# color_mode="rgb"
# batch_size=16
# label_mode="categorical"
# shuffle=True
# seed=42
#
# ```
# The HPS gave us:
#
#
#
# ```
#  {'conv_1_num_filters': 32,
#  'conv_1_kernel_size': 11,
#  'conv_1_strides': 4,
#  '1_activation': 'softmax',
#  '1_pool_size': 4,
#  '1_strides': 3,
#  'conv_2_num_filters': 168,
#  'conv_2_kernel_size': 5,
#  'conv_2_padding': 'same',
#  '2_activation': 'relu',
#  '2_pool_size': 3,
#  '2_strides': 2,
#  'conv_3_num_filters': 208,
#  'conv_3_kernel_size': 7,
#  'conv_3_padding': 'same',
#  '3_activation': 'softmax',
#  '3_pool_size': 4,
#  '3_strides': 2,
#  'dropout': 0.3,
#  'dense_activation': 'softmax',
#  'learning_rate': 0.001,
#  'optimizer': 'adam',
#  'tuner/epochs': 100,
#  'tuner/initial_epoch': 34,
#  'tuner/bracket': 4,
#  'tuner/round': 4,
#  'tuner/trial_id': '0143'}
# ```
# ![grafik.png](data:image/png;base64,...)

# %% [markdown]
# #### Training Curve Custom Architecture
# ![grafik.png](data:image/png;base64,...)

# %% [markdown]
# #### Custom Architecture evaluation on test dataset

# %% [markdown]
# ```
# [test loss, categorical_accuracy, test accuracy]: [0.28302156925201416, 0.875, 0.9769439697265625]
#
# ```

# %% [markdown]
# ## Conclusion

# %% [markdown]
# | Model | Accuracy on Test Dataset before HPS | Accuracy on Test Dataset after HPS|
# | :---: | :---: | :---: |
# | LeNet(128,128,3)  |  -- | 0.8750 |
# | AlexNet(128,128,3) |  -- | 0.8828 |
# | **Custom (128,128,3**) |  -- | **0.9140** |
# | LeNet(256,256,3) | --| 0.859 |
# | AlexNet(256,256,3) |  -- | 0.7891 |
# | Custom(256,256,3) |  -- | 0.8750 |

# %% [markdown]
# All networks showed superior performance when using images that were 128x128 in size. The Custom Architecture achieved the highest categorical accuracy (91.40%) on the test dataset, so we were able to increase the accuracy by --%, as previously mentioned. The training curves for all models indicate that none of them are overfitting, as the validation accuracy is consistently higher than the training accuracy. However, when evaluated against the test set, they were unable to achieve a similar score to the validation accuracy (which was for example approximately 96% for the Custom 128x128). The Hyperparameters for each model that were discovered during the HPS can be found in their respective sections.
